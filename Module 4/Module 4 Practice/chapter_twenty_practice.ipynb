# %%
import os
os.listdir('.')
# Out:
# ['.git', 'Module 1', 'Module 2', 'Module 3', 'Module 4', 'README.md']

# %%
import os
os.listdir('..')
# Out:
# ['.git', 'Module 1', 'Module 2', 'Module 3', 'Module 4', 'README.md']

# %%
test1 = "This is a test of the emergency text system."
with open("test.txt", 'wt') as file:
    file.write(test1)

# %%
with open("test.txt", 'r') as file:
    test2 = file.read()
print(test2, test1)
# Out:
# This is a test of the emergency text system. This is a test of the emergency text system.

# %% [markdown]
# Test1 and test2 are the same.

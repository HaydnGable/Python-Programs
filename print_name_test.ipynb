# %%
"""
Different types of variables and whether or not they are mutuable:
Immutable variables: bool, int, float, complex, str, tuple, bytes, frozenset
Mutable variables: list, bytearray, set, dict
"""
my_name = "Haydn"
print("Hello! My name is", my_name)
# Out:
# Hello! My name is Haydn
